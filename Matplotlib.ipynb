# %%
# drwaing line 
# x(1,2) y(6,60) it will be decleare as 
x = np.array([1,6])
y = np.array([2,60]) 

plt.plot(x,y)
plt.show()

# %%
# drwaing line 
# x(1,2) y(6,60) it will be decleare as 
x = np.array([1,6])
y = np.array([2,60]) 

plt.plot(x,y , 'o')
plt.show()

# %%
# taking multiple points
xpoints = np.array([10,34,56,74])
ypoints = np.array([45,34,90,65,])

plt.plot(xpoints,ypoints)
plt.show()

# %%
# without using X axis points it will automatically consider
#xpoints = np.array([10,34,56,74])
ypoints = np.array([45,34,90,65,])

plt.plot(ypoints)
plt.show()

# %%
xpoints = np.array([10,34,56,74])
ypoints = np.array([45,34,90,65,])

plt.plot(xpoints,ypoints , marker = '*')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# '^'	Triangle Up
# '<'	Triangle Left
# '>'	Triangle Right
# '1'	Tri Down
# '2'	Tri Up
# '3'	Tri Left
# '4'	Tri Right
# '|'	Vline
# '_'	Hline
# '+'	Plus
# 'P'	Plus (filled)
# 's'	Square
# 'D'	Diamond
# 'd'	Diamond (thin)
# 'p'	Pentagon
# 'H'	Hexagon
# 'h'	Hexagon
# 'v'	Triangle Down
# 'o'	Circle
# '*'	Star
# '.'	Point
# ','	Pixel
# 'X'	X (filled)

# %% [markdown]
# '-'	Solid line
# ':'	Dotted line
# '--'	Dashed line
# '-.'	Dashed/dotted line

# %%
a = np.array([10,34,56,74])
b= np.array([45,73,90,83,])
c = np.array([23,49,24,62])
d = np.array([64,84,68,13])
e = np.array([65,67,88,45])

plt.plot(a ,'D:r') 
plt.plot(b ,'*-.b') 
plt.plot(c ,'D--g') 
plt.plot(e ,'*-m') 
# using fmt 
plt.show()

# %%
y = np.array([45,34,90,65,])

plt.plot(ypoints , marker = 'o' , ms = 10 , mfc = 'r') # ms = marker size , mfc = marker face color
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'b' , linestyle = 'dotted' , linewidth = '5.5')
plt.show()

# %%
# labeling 
a = np.array([10,34,56,74])
b= np.array([45,73,90,83,])
c = np.array([23,49,24,62])
d = np.array([64,84,68,13])
e = np.array([65,67,88,45])

plt.plot(a ,'D:r') 
plt.plot(b ,'*-.b') 
plt.plot(c ,'D--g' , linewidth = '2') 
plt.plot(e ,'*-m' , linewidth = '3') 

font1 = {'family':'serif','color':'blue','size':20}
plt.title("comparison", fontdict=font1 , loc ='left')
plt.xlabel('smart')
plt.ylabel('oversmart')



plt.grid()
plt.show()

# %%
x = np.array([44,41,55,15])
y = np.array([28,84,21,77])

plt.subplot(1,2,2)
plt.plot(x,y , color = 'r' , linewidth = '2' , marker = 'o')
plt.grid()
plt.title('thor')


x = np.array([55,35,13,63])
y = np.array([15,56,23,45])

plt.subplot(1,2,1)
plt.plot(x,y , color = 'g' , linewidth = '1' , marker = 'v', linestyle = 'dotted')
plt.title('loki')

plt.suptitle('ODIN')
# Out:
# Text(0.5, 0.98, 'ODIN')

# %% [markdown]
# ### scatter plot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)


x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)


x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([105,90,99,90,95,94,100,103,87,94,78,77,85,45,66])
plt.scatter(x, y)

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5,cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# ### bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.random.randint(4,size=(4))
plt.subplot(1,2,1)
plt.bar(x,y, color = 'red' ) # bar
plt.grid()

x = ["A", "B", "C", "D"]
y = np.random.randint(4,size=(4))
plt.subplot(1,2,2)
plt.barh(x,y , color = 'green') # barh 
plt.grid()

plt.show()

# %% [markdown]
# ### histogram

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ### piecharts

# %%
x = np.array([2,3,4,5])
fruits = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(x  , labels= fruits , startangle= 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x17b180ab0d0>,
# ...
#  [Text(-0.4772721329129438, 0.9910657451172095, 'Apples'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'Bananas'),
#   Text(1.0298943251329445e-07, -1.0999999999999954, 'Cherries'),
#   Text(0.9910656780890369, 0.47727227209834605, 'Dates')])
